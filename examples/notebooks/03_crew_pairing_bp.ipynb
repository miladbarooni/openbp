# %% [markdown]
# # Airline Crew Pairing: Branch-and-Price vs Column Generation
#
# This notebook compares two approaches for solving the Crew Pairing Problem (CPP):
#
# 1. **Column Generation (CG)** - Solves LP relaxation with column generation
# 2. **Branch-and-Price (B&P)** - Full branch-and-bound tree with column generation at each node
#
# ## Problem Description
#
# Given:
# - A set of flight legs that must be covered
# - Crew regulations (duty time limits, rest requirements)
# - Crew bases (airports where crews are stationed)
#
# Find a minimum cost set of **pairings** (legal crew schedules) that cover all flights exactly once.
#
# ## Why B&P for Crew Pairing?
#
# Crew pairing is a **set partitioning** problem:
# - Each flight must be in *exactly one* pairing (equality constraints)
# - LP relaxation can be quite fractional
# - Ryan-Foster branching works well for this structure
#
# B&P is essential when:
# - You need proven optimal solutions
# - IP rounding from CG doesn't give feasible solutions
# - The integrality gap is significant

# %%
# OpenCG should be installed as a package (pip install -e path/to/opencg or pip install opencg)
# OpenBP should also be installed (pip install -e path/to/openbp)

# If running from the openbp repo without installation, uncomment:
# import sys
# sys.path.insert(0, "../..")  # Add openbp root

# %%
# Import OpenCG for column generation
from opencg.applications.crew_pairing import (
    solve_crew_pairing,
    CrewPairingConfig,
)
from opencg.parsers import KasirzadehParser

# Import OpenBP for branch-and-price
from openbp.solver import BranchAndPrice, BPConfig, BPStatus
from openbp.branching import RyanFosterBranching
from openbp.selection import create_selector

import time

# %% [markdown]
# ## Loading a Crew Pairing Instance
#
# We use the **Kasirzadeh dataset**, a standard benchmark for crew pairing problems.

# %%
# Check for Kasirzadeh dataset using OpenCG's config
from opencg.config import get_data_path

data_path = get_data_path() / "kasirzadeh"

if data_path.exists():
    print(f"Kasirzadeh data found at: {data_path}")
    instances = sorted(data_path.iterdir())
    for inst in instances:
        if inst.is_dir():
            print(f"  {inst.name}")
else:
    print(f"Kasirzadeh data not found at: {data_path}")
    print("Set OPENCG_DATA_PATH environment variable or configure opencg.config")

# %%
# Load a small instance for testing
# Instance1 is one of the smaller instances
instance_path = data_path / "instance2" / "instance2"

if instance_path.exists():
    parser = KasirzadehParser()
    problem = parser.parse(str(instance_path))
    
    print(f"Instance loaded: {problem.name}")
    print(f"  Flights: {len(problem.cover_constraints)}")
    print(f"  Network nodes: {problem.network.num_nodes}")
    print(f"  Network arcs: {problem.network.num_arcs}")
    print(f"  Resources: {len(problem.resources)}")
    for r in problem.resources:
        print(f"    - {r.name}")
else:
    print(f"Instance not found at: {instance_path}")
# Out:
# Instance loaded: instance2
#   Flights: 1500
#   Network nodes: 3002
#   Network arcs: 9078
#   Resources: 3
#     - duty_time
#     - flight_time
#     - duty_days

# %% [markdown]
# ## Approach 1: Column Generation Only
#
# First, let's solve with OpenCG's column generation.

# %%
if 'problem' in dir():
    # Configure CG solver
    config = CrewPairingConfig(
        max_iterations=30,
        pricing_max_columns=100,
        cols_per_source=3,
        verbose=True,
    )
    
    # Solve with CG
    start = time.time()
    cg_solution = solve_crew_pairing(problem, config)
    cg_time = time.time() - start
    
    print(f"\n" + "="*60)
    print("COLUMN GENERATION RESULTS")
    print("="*60)
    print(f"LP Objective: {cg_solution.objective:.2f}")
    print(f"Pairings used: {cg_solution.num_pairings}")
    print(f"Coverage: {cg_solution.coverage_pct:.1f}%")
    print(f"Uncovered flights: {len(cg_solution.uncovered_flights)}")
    print(f"Solve time: {cg_time:.2f}s")
    print(f"CG iterations: {cg_solution.iterations}")
    print(f"Total columns: {cg_solution.num_columns}")
# Out:
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# FastPerSourcePricing: prebuilding 754 networks...
#   Prebuilt in 16.35s
# Generating initial columns...
#   Found 100 initial columns
# Running Column Generation...
#  Iter       Objective    Columns    New   Coverage
# --------------------------------------------------
# LP has 1500 rows; 1600 cols; 1819 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 98 rows, 179 cols, 318 nonzeros  0s
# Dependent equations search running on 87 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.00s (limit = 1000.00s)
# 87 rows, 156 cols, 285 nonzeros  0s
# Presolve reductions: rows 87(-1413); columns 156(-1444); nonzeros 285(-1534)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Ph1: 0(0) 0s
#          48     1.3290001710e+09 Pr: 0(0) 0s
#
# Performed postsolve
# Solving the original LP from the solution after postsolve
# Using EKK primal simplex solver
#   Iteration        Objective     Infeasibilities num(sum)
#          48     1.3290001221e+09 Pr: 0(0); Du: 1(999998) 0s
#          49     1.3290001710e+09 Pr: 0(0) 0s
# Required 1 simplex iterations after postsolve
#
# Model status        : Optimal
# Simplex   iterations: 49
# Objective value     :  1.3290001710e+09
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.00
#     0   1329000171.00       1600    100      12.2%
# LP has 1500 rows; 1700 cols; 2716 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -5.7601280423e+08 Ph1: 232(896); Du: 105(5.76013e+08) 0s
#         140     1.2600002400e+09 Pr: 0(0); Du: 0(1.67787e-08) 0s
#
# Model status        : Optimal
# Simplex   iterations: 140
# Objective value     :  1.2600002400e+09
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.01
# LP has 1500 rows; 1800 cols; 3543 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.6500881786e+08 Ph1: 222(2088.54); Du: 111(3.65009e+08) 0s
#         250     1.2259002741e+09 Pr: 0(0); Du: 0(1.07102e-08) 0s
#
# Model status        : Optimal
# Simplex   iterations: 250
# Objective value     :  1.2259002741e+09
# P-D objective error :  1.9448448136e-16
# HiGHS run time      :          0.02
# LP has 1500 rows; 1900 cols; 4406 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.2240740403e+08 Ph1: 216(1156.33); Du: 159(3.22407e+08) 0s
#         498     1.1898740965e+09 Pr: 0(0); Du: 0(1.69966e-08) 0s
#
# Model status        : Optimal
# Simplex   iterations: 498
# Objective value     :  1.1898740965e+09
# P-D objective error :  2.0037294676e-16
# HiGHS run time      :          0.05
# LP has 1500 rows; 2000 cols; 5291 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.0977107412e+08 Ph1: 219(4629.48); Du: 141(2.09771e+08) 0s
#         609     1.1807351125e+09 Pr: 0(0); Du: 0(4.19095e-09) 0s
#         609     1.1807351125e+09 Pr: 0(0); Du: 0(4.19095e-09) 0s
#
# Model status        : Optimal
# Simplex   iterations: 609
# Objective value     :  1.1807351125e+09
# P-D objective error :  5.0480962344e-16
# HiGHS run time      :          0.08
# LP has 1500 rows; 2100 cols; 6141 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.3091755998e+08 Ph1: 214(3461.47); Du: 140(1.30918e+08) 0s
#         624     1.1726614844e+09 Pr: 0(0); Du: 0(2.30691e-07) 0s
#
# Model status        : Optimal
# Simplex   iterations: 624
# Objective value     :  1.1726614844e+09
# P-D objective error :  1.0165703495e-16
# HiGHS run time      :          0.12
#     5   1172661484.36       2100    100      22.5%
# LP has 1500 rows; 2200 cols; 6995 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.9781616847e+08 Ph1: 290(2707.62); Du: 179(2.97816e+08) 0s
#        1042     1.1060003940e+09 Pr: 0(0); Du: 0(5.67463e-07) 0s
#        1042     1.1060003940e+09 Pr: 0(0); Du: 0(5.67463e-07) 0s
#
# Model status        : Optimal
# Simplex   iterations: 1042
# Objective value     :  1.1060003940e+09
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.19
# LP has 1500 rows; 2300 cols; 7851 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -4.9101191592e+08 Ph1: 354(7614.47); Du: 270(4.91012e+08) 0s
#        1069     1.0248004752e+09 Pr: 0(0); Du: 0(1.61864e-06) 0s
#        1069     1.0248004752e+09 Pr: 0(0); Du: 0(1.61864e-06) 0s
#
# Model status        : Optimal
# Simplex   iterations: 1069
# Objective value     :  1.0248004752e+09
# P-D objective error :  5.8162194680e-17
# HiGHS run time      :          0.27
# LP has 1500 rows; 2400 cols; 8662 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -4.2241094227e+08 Ph1: 338(24067.9); Du: 332(4.22411e+08) 0s
#        1559     1.0043275099e+09 Pr: 0(0); Du: 0(5.46264e-07) 0s
#        1559     1.0043275099e+09 Pr: 0(0); Du: 0(5.46264e-07) 0s
#
# Model status        : Optimal
# Simplex   iterations: 1559
# Objective value     :  1.0043275099e+09
# P-D objective error :  5.9347816483e-17
# HiGHS run time      :          0.38
# LP has 1500 rows; 2500 cols; 9482 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.8825844055e+08 Ph1: 362(7063.11); Du: 388(2.88258e+08) 0s
#        1616     9.8093606456e+08 Pr: 0(0); Du: 0(6.56582e-08) 0s
#        1616     9.8093606456e+08 Pr: 0(0); Du: 0(6.56582e-08) 0s
#
# Model status        : Optimal
# Simplex   iterations: 1616
# Objective value     :  9.8093606456e+08
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.48
# LP has 1500 rows; 2600 cols; 10297 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.1224078965e+08 Ph1: 346(109010); Du: 376(2.12241e+08) 0s
#        2348     9.6594192379e+08 Pr: 0(0); Du: 4(5.59079e-06) 1s
#        2348     9.6594192379e+08 Pr: 0(0); Du: 4(5.59079e-06) 1s
#
# Model status        : Optimal
# Simplex   iterations: 2348
# Objective value     :  9.6594192379e+08
# P-D objective error :  6.1706240589e-16
# HiGHS run time      :          0.72
#    10    965941923.79       2600    100      36.3%
# LP has 1500 rows; 2700 cols; 11119 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.0043790608e+08 Ph1: 394(8024.02); Du: 413(3.00438e+08) 1s
#        2397     9.3252953449e+08 Pr: 0(0); Du: 0(1.47283e-06) 1s
#
# Model status        : Optimal
# Simplex   iterations: 2397
# Objective value     :  9.3252953449e+08
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.94
# LP has 1500 rows; 2800 cols; 11971 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.5604782694e+08 Ph1: 372(9477.17); Du: 339(1.56048e+08) 1s
#        3053     9.2075057925e+08 Pr: 0(0); Du: 0(2.15477e-06) 1s
#        3053     9.2075057925e+08 Pr: 0(0); Du: 0(2.15477e-06) 1s
#
# Model status        : Optimal
# Simplex   iterations: 3053
# Objective value     :  9.2075057925e+08
# P-D objective error :  6.4734843601e-16
# HiGHS run time      :          1.24
# LP has 1500 rows; 2900 cols; 12817 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.6675826491e+08 Ph1: 479(10081.5); Du: 546(3.66758e+08) 1s
#        2741     8.4444402125e+08 Pr: 0(0); Du: 0(2.80905e-06) 1s
#        2741     8.4444402125e+08 Pr: 0(0); Du: 0(2.80905e-06) 1s
#
# Model status        : Optimal
# Simplex   iterations: 2741
# Objective value     :  8.4444402125e+08
# P-D objective error :  3.5292241546e-16
# HiGHS run time      :          1.50
# LP has 1500 rows; 3000 cols; 13634 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.3832617920e+08 Ph1: 446(22174.9); Du: 421(2.38326e+08) 1s
#        2592     8.3062118220e+08 Pr: 0(0); Du: 0(2.891e-06) 2s
#        2592     8.3062118220e+08 Pr: 0(0); Du: 0(2.891e-06) 2s
#
# Model status        : Optimal
# Simplex   iterations: 2592
# Objective value     :  8.3062118220e+08
# P-D objective error :  4.3055471748e-16
# HiGHS run time      :          1.75
# LP has 1500 rows; 3100 cols; 14515 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.7238763811e+08 Ph1: 455(116830); Du: 493(1.72388e+08) 2s
#        4312     8.1876991200e+08 Pr: 0(0); Du: 4(1.14616e-05) 2s
#        4312     8.1876991200e+08 Pr: 0(0); Du: 4(1.14616e-05) 2s
#
# Model status        : Optimal
# Simplex   iterations: 4312
# Objective value     :  8.1876991200e+08
# P-D objective error :  1.0919669348e-15
# HiGHS run time      :          2.14
#    15    818769912.00       3100    100      46.1%
# LP has 1500 rows; 3200 cols; 15339 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -4.2793781156e+08 Ph1: 525(87182.3); Du: 635(4.27938e+08) 2s
#        4445     7.4861741805e+08 Pr: 0(0); Du: 5(1.07704e-05) 3s
#        4445     7.4861741805e+08 Pr: 0(0); Du: 5(1.07704e-05) 3s
#
# Model status        : Optimal
# Simplex   iterations: 4445
# Objective value     :  7.4861741805e+08
# P-D objective error :  7.9619633872e-17
# HiGHS run time      :          2.61
# LP has 1500 rows; 3300 cols; 16185 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.5440896419e+08 Ph1: 510(22711.8); Du: 676(3.54409e+08) 3s
#        5025     7.1888967000e+08 Pr: 0(0); Du: 0(1.11137e-05) 3s
#        5025     7.1888967000e+08 Pr: 0(0); Du: 0(1.11137e-05) 3s
#
# Model status        : Optimal
# Simplex   iterations: 5025
# Objective value     :  7.1888967000e+08
# P-D objective error :  3.3164835841e-16
# HiGHS run time      :          3.16
# LP has 1500 rows; 3400 cols; 17049 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -4.6173386855e+08 Ph1: 588(39254.8); Du: 724(4.61734e+08) 3s
#        5312     6.4761511020e+08 Pr: 0(0); Du: 1(4.95696e-06) 4s
#        5312     6.4761511020e+08 Pr: 0(0); Du: 1(4.95696e-06) 4s
#
# Model status        : Optimal
# Simplex   iterations: 5312
# Objective value     :  6.4761511020e+08
# P-D objective error :  5.5222286007e-16
# HiGHS run time      :          3.72
# LP has 1500 rows; 3500 cols; 17887 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.7238157425e+08 Ph1: 560(35937); Du: 670(2.72382e+08) 4s
#        5649     6.3407229450e+08 Pr: 0(0); Du: 3(1.08487e-05) 4s
#        5649     6.3407229450e+08 Pr: 0(0); Du: 3(1.08487e-05) 4s
#
# Model status        : Optimal
# Simplex   iterations: 5649
# Objective value     :  6.3407229450e+08
# P-D objective error :  4.7001458071e-16
# HiGHS run time      :          4.33
# LP has 1500 rows; 3600 cols; 18720 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.5065061058e+08 Ph1: 565(60606.7); Du: 741(2.50651e+08) 4s
#        7512     6.1705088295e+08 Pr: 0(0); Du: 1(1.0343e-05) 5s
#        7512     6.1705088295e+08 Pr: 0(0); Du: 1(1.0343e-05) 5s
#
# Model status        : Optimal
# Simplex   iterations: 7512
# Objective value     :  6.1705088295e+08
# P-D objective error :  9.6595996172e-17
# HiGHS run time      :          5.28
#    20    617050882.95       3600    100      59.5%
# LP has 1500 rows; 3700 cols; 19633 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.8862655550e+08 Ph1: 639(40605.6); Du: 751(3.88627e+08) 5s
#        6401     5.6199227250e+08 Pr: 0(0); Du: 12(1.1468e-05) 6s
#        6401     5.6199227250e+08 Pr: 0(0); Du: 12(1.1468e-05) 6s
#
# Model status        : Optimal
# Simplex   iterations: 6401
# Objective value     :  5.6199227250e+08
# P-D objective error :  6.3635727008e-16
# HiGHS run time      :          6.02
# LP has 1500 rows; 3800 cols; 20455 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.2161581101e+08 Ph1: 633(51881.4); Du: 749(3.21616e+08) 6s
#        7346     5.3763447986e+08 Pr: 0(0); Du: 11(1.37204e-05) 7s
#        7346     5.3763447986e+08 Pr: 0(0); Du: 11(1.37204e-05) 7s
#
# Model status        : Optimal
# Simplex   iterations: 7346
# Objective value     :  5.3763447986e+08
# P-D objective error :  3.3259387345e-16
# HiGHS run time      :          6.88
# LP has 1500 rows; 3900 cols; 21277 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.3451040238e+08 Ph1: 627(46844.5); Du: 802(2.3451e+08) 7s
#        7934     5.1133599180e+08 Pr: 0(0); Du: 0(9.69926e-06) 8s
#        7934     5.1133599180e+08 Pr: 0(0); Du: 0(9.69926e-06) 8s
#
# Model status        : Optimal
# Simplex   iterations: 7934
# Objective value     :  5.1133599180e+08
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          7.81
# LP has 1500 rows; 4000 cols; 22077 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.1374875900e+07 Ph1: 559(14346.6); Du: 695(3.13749e+07) 8s
#        8769     5.1100098900e+08 Pr: 0(0); Du: 1(1.48501e-05) 9s
#        8769     5.1100098900e+08 Pr: 0(0); Du: 1(1.48501e-05) 9s
#
# Model status        : Optimal
# Simplex   iterations: 8769
# Objective value     :  5.1100098900e+08
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          9.22
# LP has 1500 rows; 4100 cols; 22949 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -5.2201306074e+08 Ph1: 758(114274); Du: 1013(5.22013e+08) 9s
#       10380     4.2375107625e+08 Pr: 0(0); Du: 2(1.7071e-05) 11s
#       10380     4.2375107625e+08 Pr: 0(0); Du: 2(1.7071e-05) 11s
#
# Model status        : Optimal
# Simplex   iterations: 10380
# Objective value     :  4.2375107625e+08
# P-D objective error :  1.4065957126e-16
# HiGHS run time      :         10.76
#    25    423751076.25       4100    100      73.1%
# LP has 1500 rows; 4200 cols; 23778 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.7651579193e+08 Ph1: 723(395134); Du: 1039(3.76516e+08) 11s
#        9206     3.9974853411e+08 Pr: 0(0); Du: 0(9.54235e-06) 12s
#        9206     3.9974853411e+08 Pr: 0(0); Du: 0(9.54235e-06) 12s
#
# Model status        : Optimal
# Simplex   iterations: 9206
# Objective value     :  3.9974853411e+08
# P-D objective error :  1.1928427922e-15
# HiGHS run time      :         12.48
# LP has 1500 rows; 4300 cols; 24615 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.1139043408e+08 Ph1: 688(87259.7); Du: 956(1.1139e+08) 12s
#       11399     3.9222300644e+08 Pr: 0(0); Du: 6(2.36209e-05) 14s
#       11399     3.9222300644e+08 Pr: 0(0); Du: 6(2.36209e-05) 14s
#
# Model status        : Optimal
# Simplex   iterations: 11399
# Objective value     :  3.9222300644e+08
# P-D objective error :  5.3188174335e-16
# HiGHS run time      :         14.32
# LP has 1500 rows; 4400 cols; 25409 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.9558826312e+08 Ph1: 769(381762); Du: 1040(2.95588e+08) 14s
#       12364     3.4863511363e+08 Pr: 0(0); Du: 0(1.63774e-05) 16s
#       12364     3.4863511363e+08 Pr: 0(0); Du: 0(1.63774e-05) 16s
#
# Model status        : Optimal
# Simplex   iterations: 12364
# Objective value     :  3.4863511363e+08
# P-D objective error :  5.9837993437e-16
# HiGHS run time      :         16.29
# LP has 1500 rows; 4500 cols; 26255 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Solving LP with useful basis so presolve not used
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.1637476348e+08 Ph1: 729(110477); Du: 1045(2.16375e+08) 16s
#       15299     3.3395620202e+08 Pr: 0(0); Du: 372(0.000173861) 21s
#       23149     3.3395620202e+08 Pr: 0(0); Du: 113(4.79494e-05) 26s
#       23284     3.3395620202e+08 Pr: 0(0); Du: 14(2.53281e-05) 26s
#       23284     3.3395620202e+08 Pr: 0(0); Du: 14(2.53281e-05) 26s
#
# Model status        : Optimal
# Simplex   iterations: 23284
# Objective value     :  3.3395620202e+08
# P-D objective error :  6.2468148560e-16
# HiGHS run time      :         26.38
#
# ============================================================
# COLUMN GENERATION RESULTS
# ============================================================
# LP Objective: 333956202.02
# Pairings used: 619
# Coverage: 78.5%
# Uncovered flights: 323
# Solve time: 397.30s
# CG iterations: 30
# Total columns: 4600

# %% [markdown]
# ## Understanding Crew Pairing Structure
#
# ### Pairing Properties
#
# Each pairing (route in VRP terms) represents a complete crew schedule:
# - Starts at a crew base (home airport)
# - Contains sequence of flights and rests
# - Ends at the same crew base
# - Respects duty time limits
#
# ### Network Structure
#
# The time-space network has:
# - **Flight arcs**: Actual flights to cover
# - **Connection arcs**: Short waits between flights
# - **Rest arcs**: Overnight hotel stays
# - **Source/Sink arcs**: Base departures/returns

# %%
if 'problem' in dir():
    from opencg.core.arc import ArcType
    
    # Count arc types
    arc_types = {}
    for arc in problem.network.arcs:
        t = arc.arc_type.name
        arc_types[t] = arc_types.get(t, 0) + 1
    
    print("Network Arc Types:")
    print("-"*40)
    for t, count in sorted(arc_types.items()):
        print(f"  {t:<15}: {count:>6}")
    print("-"*40)
    print(f"  {'Total':<15}: {sum(arc_types.values()):>6}")
# Out:
# Network Arc Types:
# ----------------------------------------
#   CONNECTION     :   2094
#   FLIGHT         :   1500
#   OVERNIGHT      :   3976
#   SINK_ARC       :    754
#   SOURCE_ARC     :    754
# ----------------------------------------
#   Total          :   9078

# %% [markdown]
# ## Analyzing Solution Quality
#
# Let's analyze the CG solution to understand the structure of pairings.

# %%
if 'cg_solution' in dir() and cg_solution.pairings:
    # Distribution of pairing sizes
    sizes = [len(p.covered_items) for p in cg_solution.pairings]
    costs = [p.cost for p in cg_solution.pairings]
    
    print("Pairing Statistics:")
    print("-"*40)
    print(f"  Total pairings: {len(sizes)}")
    print(f"  Average flights per pairing: {sum(sizes)/len(sizes):.1f}")
    print(f"  Min/Max pairing size: {min(sizes)} / {max(sizes)}")
    print(f"  Average pairing cost: {sum(costs)/len(costs):.2f}")
    print(f"  Total cost: {sum(costs):.2f}")
    
    print("\nSample pairings (first 5):")
    for i, pairing in enumerate(cg_solution.pairings[:5]):
        print(f"  Pairing {i+1}: {len(pairing.covered_items)} flights, cost={pairing.cost:.2f}")
# Out:
# Pairing Statistics:
# ----------------------------------------
#   Total pairings: 619
#   Average flights per pairing: 8.1
#   Min/Max pairing size: 2 / 14
#   Average pairing cost: 8.12
#   Total cost: 5026.00
#
# Sample pairings (first 5):
#   Pairing 1: 2 flights, cost=2.00
#   Pairing 2: 2 flights, cost=2.00
#   Pairing 3: 2 flights, cost=2.00
#   Pairing 4: 2 flights, cost=2.00
#   Pairing 5: 2 flights, cost=2.00

# %% [markdown]
# ## Why Branch-and-Price for Crew Pairing?
#
# The LP solution from column generation may have:
#
# 1. **Fractional pairings**: Using pairing A 0.5 times and pairing B 0.5 times
# 2. **Coverage issues**: Some flights may be covered fractionally
# 3. **Suboptimal rounding**: Simply rounding may violate constraints
#
# ### Ryan-Foster Branching
#
# For set partitioning, Ryan-Foster branching is effective:
# - Choose two flights $(i, j)$ that are fractionally together
# - Left branch: Flights $i$ and $j$ must be in the **same** pairing
# - Right branch: Flights $i$ and $j$ must be in **different** pairings
#
# This eliminates fractional solutions systematically.

# %%
# Demonstrate Ryan-Foster branching concept
print("Ryan-Foster Branching for Crew Pairing")
print("="*50)
print()
print("Scenario: Two pairings with fractional values")
print("  Pairing A: covers flights {1, 2, 3}, value = 0.5")
print("  Pairing B: covers flights {1, 4, 5}, value = 0.5")
print()
print("Flight 1 is fractionally covered by both pairings.")
print("Branch on flights (1, 2):")
print()
print("  Left branch: 1 and 2 must be TOGETHER")
print("    -> Forces Pairing A (or similar)")
print("    -> Removes Pairing B from pool")
print()
print("  Right branch: 1 and 2 must be SEPARATE")
print("    -> Removes Pairing A from pool")
print("    -> Keeps Pairing B (and others with 1 but not 2)")
# Out:
# Ryan-Foster Branching for Crew Pairing
# ==================================================
#
# Scenario: Two pairings with fractional values
#   Pairing A: covers flights {1, 2, 3}, value = 0.5
#   Pairing B: covers flights {1, 4, 5}, value = 0.5
#
# Flight 1 is fractionally covered by both pairings.
# Branch on flights (1, 2):
#
#   Left branch: 1 and 2 must be TOGETHER
#     -> Forces Pairing A (or similar)
#     -> Removes Pairing B from pool
#
#   Right branch: 1 and 2 must be SEPARATE
#     -> Removes Pairing A from pool
#     -> Keeps Pairing B (and others with 1 but not 2)

# %% [markdown]
# ## Coverage Analysis
#
# Achieving 100% coverage is critical in crew pairing. Let's analyze coverage patterns.

# %%
if 'cg_solution' in dir():
    total_flights = len(problem.cover_constraints)
    covered_flights = total_flights - len(cg_solution.uncovered_flights)
    
    print("Coverage Analysis")
    print("="*50)
    print(f"Total flights: {total_flights}")
    print(f"Covered: {covered_flights} ({100*covered_flights/total_flights:.1f}%)")
    print(f"Uncovered: {len(cg_solution.uncovered_flights)}")
    
    if cg_solution.uncovered_flights:
        print(f"\nUncovered flight IDs: {sorted(cg_solution.uncovered_flights)[:20]}")
        if len(cg_solution.uncovered_flights) > 20:
            print(f"  ... and {len(cg_solution.uncovered_flights) - 20} more")
    else:
        print("\nAll flights covered!")
# Out:
# Coverage Analysis
# ==================================================
# Total flights: 1500
# Covered: 1177 (78.5%)
# Uncovered: 323
#
# Uncovered flight IDs: [49, 86, 87, 138, 139, 190, 191, 234, 235, 261, 262, 331, 332, 383, 384, 435, 436, 487, 488, 539]
#   ... and 303 more

# %% [markdown]
# ## Comparison: CG vs B&P
#
# Let's summarize the key differences for crew pairing.

# %%
print("\n" + "="*60)
print("COMPARISON: CG vs B&P FOR CREW PAIRING")
print("="*60)
print()
print("| Aspect             | Column Generation | Branch-and-Price |")
print("|" + "-"*20 + "|" + "-"*19 + "|" + "-"*18 + "|")
print("| Solution Type      | LP relaxation     | Optimal integer  |")
print("| Optimality Proof   | No                | Yes              |")
print("| Speed              | Fast              | Slower           |")
print("| Coverage Guarantee | May be fractional | 100% or infeas.  |")
print("| Branching          | None              | Ryan-Foster      |")
print()
# Out:
# ============================================================
# COMPARISON: CG vs B&P FOR CREW PAIRING
# ============================================================
#
# | Aspect             | Column Generation | Branch-and-Price |
# |--------------------|-------------------|------------------|
# | Solution Type      | LP relaxation     | Optimal integer  |
# | Optimality Proof   | No                | Yes              |
# | Speed              | Fast              | Slower           |
# | Coverage Guarantee | May be fractional | 100% or infeas.  |
# | Branching          | None              | Ryan-Foster      |

# %%
if 'cg_solution' in dir():
    print("Results for this instance:")
    print("-"*40)
    print(f"CG LP Objective: {cg_solution.objective:.2f}")
    print(f"CG Coverage: {cg_solution.coverage_pct:.1f}%")
    print(f"CG Time: {cg_time:.2f}s")
    print()
    print("B&P would:")
    print("  - Start from CG solution")
    print("  - Branch on fractional pairings")
    print("  - Prove optimality or find better integer solution")
    print("  - Guarantee 100% coverage or prove infeasibility")
# Out:
# Results for this instance:
# ----------------------------------------
# CG LP Objective: 333956202.02
# CG Coverage: 78.5%
# CG Time: 397.30s
#
# B&P would:
#   - Start from CG solution
#   - Branch on fractional pairings
#   - Prove optimality or find better integer solution
#   - Guarantee 100% coverage or prove infeasibility

# %% [markdown]
# ## Summary
#
# ### Key Insights for Crew Pairing
#
# 1. **Complex Structure**: Time-space networks with multiple resources
# 2. **Set Partitioning**: Each flight must be in exactly one pairing
# 3. **Coverage is Critical**: 100% coverage is a hard requirement
# 4. **Large Instances**: Real-world instances have thousands of flights
#
# ### When to Use B&P for Crew Pairing
#
# - Need proven optimal solutions for cost comparison
# - CG solution has coverage issues
# - IP rounding gives infeasible solutions
# - Benchmarking solver performance
#
# ### Comparison with Other Problems
#
# | Problem | Constraints | Typical Gap | B&P Benefit |
# |---------|-------------|-------------|-------------|
# | Cutting Stock | Covering (≥) | Small | Modest |
# | VRP | Partitioning (=) | Medium | Significant |
# | Crew Pairing | Partitioning (=) | Can be large | Essential |
